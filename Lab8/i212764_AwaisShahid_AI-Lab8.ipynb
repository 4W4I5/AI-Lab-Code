# %% [markdown]
# ## Lab 8 - Global Search Algorithms

# %% [markdown]
# ### Simulated Annealing
# Simulated annealing is a probabilistic algorithm which tests points across a solution space to find the lowest minima. The algorithm is termed “simulated annealing” because it mirrors physical annealing, a process in which a material is repeatedly heated and cooled to elicit desired structural properties.

# %% [markdown]
# ### Understanding Simulated Annealing
# Imagine you're trying to find the highest point on a bumpy landscape, but you can only see the area around you. You start randomly, moving around, trying to climb higher. Simulated Annealing works a bit like this.
#
# <b>Start somewhere:</b> You begin at a random point on the landscape.
#
# <b>Explore:</b> You look around and take a step in a random direction, maybe up or maybe down. This step could be small or big.
#
# <b>Evaluate:</b> You see if this step makes you higher up or not. If it's higher, you keep going in that direction. If it's lower, sometimes you still go that way, but sometimes you might turn back. This decision is based on some randomness and a special formula.
#
# <b>Repeat:</b> You keep doing steps 2 and 3 many times, gradually reducing how much you explore (like cooling metal slowly in the real annealing process), until you hopefully find the highest point you can.
#
# <b>The clever part is that sometimes, even if you're going downhill a bit, you might still do it because it could lead to an even higher peak later on.</b> Simulated Annealing balances between exploring new areas (even if they seem worse) and exploiting the areas that seem better. This helps in finding the best solution, especially in complex problems where there's no straightforward way to tell which step is the best.

# %% [markdown]
# ### Algorithm
#
# <b>Initialize Parameters:</b>
# <ul>
# <li>Set the initial temperature.</li>
# <li>Choose a cooling rate (how fast the temperature decreases).</li>
# <li>Define the number of iterations or a stopping criterion.</li>
# </ul>
#
# <b>Generate Initial Solution:</b>
# <ul>
# <li>Start with any random solution to the problem.</li>
#
#    </ul>
# <b>Evaluate Initial Solution:</b>
# <ul>
# <li>
# Calculate how good or bad the initial solution is.</li>
#     </ul>
#
# <b>Iterate:</b>
# Repeat the following steps until the stopping criterion is met:
# <ul>
#
#
# <li><b>Generate Neighbor Solution:</b></li>
# <li>Make a small change to the current solution to get a neighboring solution.</li>
# <li><b>Evaluate Neighbor Solution:</b></li>
# <li>See if the neighboring solution is better or worse than the current one.</li>
# <li><b>Accept or Reject Neighbor Solution:</b></li>
# <li>If the neighboring solution is better, always accept it.</li>
# <li>If the neighboring solution is worse, sometimes accept it based on a probability.</li>
# <li><b>Update Temperature:</b></li>
# <li>Gradually reduce the temperature according to the cooling rate.</li>
# </ul>
# <b>Output:</b>
#
# Return the best solution found during the iterations.

# %% [markdown]
# ## Task
# In this scenario, we aim to solve the Travelling Salesman Problem (TSP) using the Simulated Annealing algorithm. The goal is to find the optimal tour that visits all cities exactly once while minimizing the total distance traveled.

# %%
import math
import random

# Function to calculate the total distance of a tour
def total_distance(tour, graph):
    distance = 0
    for i in range(len(tour) - 1):
        distance += graph[tour[i]][tour[i + 1]]
    distance += graph[tour[-1]][tour[0]]
    return distance
    

# Function to generate a random initial tour
def initial_tour(num_cities):
    tour = list(range(num_cities))
    random.shuffle(tour)
    return tour


# Function to perform simulated annealing algorithm
def simulated_annealing(graph, city_names, initial_temperature=1000, cooling_rate=0.95, iterations=500):
    # Generate a neighboring solution
    current_tour = initial_tour(len(city_names))
    current_distance = total_distance(current_tour, graph)
    
    # Initialize the optimal tour and distance
    optimal_tour = current_tour
    optimal_distance = current_distance
    
    # Perform simulated annealing iterations
    for _ in range(iterations):
        # Generate a neighboring solution
        neighbor_tour = current_tour.copy()
        i, j = random.sample(range(len(city_names)), 2)
        neighbor_tour[i], neighbor_tour[j] = neighbor_tour[j], neighbor_tour[i]
        
        # Evaluate the neighbor solution
        neighbor_distance = total_distance(neighbor_tour, graph)
        print(f"Neighour tour: {neighbor_tour}\ndistance: {neighbor_distance}")
        
        # Decide whether to accept the neighbor solution
        if neighbor_distance < current_distance:
            current_tour = neighbor_tour
            current_distance = neighbor_distance
            print(f"Accepted neighbour tour: {neighbor_tour}\ndistance: {neighbor_distance}")
        else:
            acceptance_probability = math.exp((current_distance - neighbor_distance) / initial_temperature)
            if random.random() < acceptance_probability:
                current_tour = neighbor_tour
                current_distance = neighbor_distance
            print(f"Picked neighbour tour: {neighbor_tour}\ndistance: {neighbor_distance}")
        
        # Update the optimal tour if needed
        if current_distance < optimal_distance:
            optimal_tour = current_tour
            optimal_distance = current_distance
        
        
        # Decrease the temperature
        initial_temperature *= cooling_rate
        print(f"\nTemperature: {initial_temperature}")
    
    return optimal_tour, optimal_distance

# Provided graph with distances and city names
city_names = ["City A", "City B", "City C", "City D", "City E"]
graph = [
    [0, 10, 15, 20, 25],   # Distances from City A to other cities
    [10, 0, 35, 25, 30],   # Distances from City B to other cities
    [15, 35, 0, 30, 45],   # Distances from City C to other cities
    [20, 25, 30, 0, 55],   # Distances from City D to other cities
    [25, 30, 45, 55, 0]    # Distances from City E to other cities
]

# Perform simulated annealing algorithm to find the optimal tour
optimal_tour, optimal_distance = simulated_annealing(graph, city_names)

# Output the optimal tour and distance
print("Optimal Tour:", optimal_tour)
print("Optimal Distance:", optimal_distance)
# Out:
# Neighour tour: [4, 2, 1, 3, 0]
# distance: 150
# Picked neighbour tour: [4, 2, 1, 3, 0]
# distance: 150
#
# Temperature: 950.0
# Neighour tour: [4, 2, 3, 1, 0]
# distance: 135
# Accepted neighbour tour: [4, 2, 3, 1, 0]
# distance: 135
#
# Temperature: 902.5
# Neighour tour: [3, 2, 4, 1, 0]
# distance: 135
# Picked neighbour tour: [3, 2, 4, 1, 0]
# distance: 135
#
# Temperature: 857.375
# Neighour tour: [3, 4, 2, 1, 0]
# distance: 165
# Picked neighbour tour: [3, 4, 2, 1, 0]
# distance: 165
#
# Temperature: 814.5062499999999
# Neighour tour: [3, 0, 2, 1, 4]
# distance: 155
# Accepted neighbour tour: [3, 0, 2, 1, 4]
# distance: 155
#
# Temperature: 773.7809374999998
# Neighour tour: [0, 3, 2, 1, 4]
# distance: 140
# Accepted neighbour tour: [0, 3, 2, 1, 4]
# distance: 140
#
# Temperature: 735.0918906249998
# Neighour tour: [2, 3, 0, 1, 4]
# distance: 135
# Accepted neighbour tour: [2, 3, 0, 1, 4]
# distance: 135
#
# Temperature: 698.3372960937497
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 663.4204312890622
# Neighour tour: [0, 4, 2, 1, 3]
# distance: 150
# Picked neighbour tour: [0, 4, 2, 1, 3]
# distance: 150
#
# Temperature: 630.2494097246091
# Neighour tour: [0, 2, 4, 1, 3]
# distance: 135
# Accepted neighbour tour: [0, 2, 4, 1, 3]
# distance: 135
#
# Temperature: 598.7369392383787
# Neighour tour: [3, 2, 4, 1, 0]
# distance: 135
# Picked neighbour tour: [3, 2, 4, 1, 0]
# distance: 135
#
# Temperature: 568.8000922764597
# Neighour tour: [3, 2, 4, 0, 1]
# distance: 135
# Picked neighbour tour: [3, 2, 4, 0, 1]
# distance: 135
#
# Temperature: 540.3600876626367
# Neighour tour: [3, 0, 4, 2, 1]
# distance: 150
# Picked neighbour tour: [3, 0, 4, 2, 1]
# distance: 150
#
# Temperature: 513.3420832795049
# Neighour tour: [0, 3, 4, 2, 1]
# distance: 165
# Picked neighbour tour: [0, 3, 4, 2, 1]
# distance: 165
#
# Temperature: 487.6749791155296
# Neighour tour: [0, 3, 1, 2, 4]
# distance: 150
# Accepted neighbour tour: [0, 3, 1, 2, 4]
# distance: 150
#
# Temperature: 463.29123015975307
# Neighour tour: [0, 3, 4, 2, 1]
# distance: 165
# Picked neighbour tour: [0, 3, 4, 2, 1]
# distance: 165
#
# Temperature: 440.1266686517654
# Neighour tour: [0, 3, 2, 4, 1]
# distance: 135
# Accepted neighbour tour: [0, 3, 2, 4, 1]
# distance: 135
#
# Temperature: 418.1203352191771
# Neighour tour: [0, 4, 2, 3, 1]
# distance: 135
# Picked neighbour tour: [0, 4, 2, 3, 1]
# distance: 135
#
# Temperature: 397.2143184582182
# Neighour tour: [1, 4, 2, 3, 0]
# distance: 135
# Picked neighbour tour: [1, 4, 2, 3, 0]
# distance: 135
#
# Temperature: 377.3536025353073
# Neighour tour: [1, 4, 2, 0, 3]
# distance: 135
# Picked neighbour tour: [1, 4, 2, 0, 3]
# distance: 135
#
# Temperature: 358.4859224085419
# Neighour tour: [1, 4, 3, 0, 2]
# distance: 155
# Picked neighbour tour: [1, 4, 3, 0, 2]
# distance: 155
#
# Temperature: 340.5616262881148
# Neighour tour: [1, 4, 2, 0, 3]
# distance: 135
# Accepted neighbour tour: [1, 4, 2, 0, 3]
# distance: 135
#
# Temperature: 323.533544973709
# Neighour tour: [1, 3, 2, 0, 4]
# distance: 125
# Accepted neighbour tour: [1, 3, 2, 0, 4]
# distance: 125
#
# Temperature: 307.35686772502356
# Neighour tour: [3, 1, 2, 0, 4]
# distance: 155
# Picked neighbour tour: [3, 1, 2, 0, 4]
# distance: 155
#
# Temperature: 291.98902433877237
# Neighour tour: [4, 1, 2, 0, 3]
# distance: 155
# Picked neighbour tour: [4, 1, 2, 0, 3]
# distance: 155
#
# Temperature: 277.38957312183373
# Neighour tour: [4, 1, 0, 2, 3]
# distance: 140
# Accepted neighbour tour: [4, 1, 0, 2, 3]
# distance: 140
#
# Temperature: 263.52009446574203
# Neighour tour: [0, 1, 4, 2, 3]
# distance: 135
# Accepted neighbour tour: [0, 1, 4, 2, 3]
# distance: 135
#
# Temperature: 250.3440897424549
# Neighour tour: [0, 1, 3, 2, 4]
# distance: 135
# Picked neighbour tour: [0, 1, 3, 2, 4]
# distance: 135
#
# Temperature: 237.82688525533214
# Neighour tour: [1, 0, 3, 2, 4]
# distance: 135
# Picked neighbour tour: [1, 0, 3, 2, 4]
# distance: 135
#
# Temperature: 225.93554099256554
# Neighour tour: [0, 1, 3, 2, 4]
# distance: 135
# Picked neighbour tour: [0, 1, 3, 2, 4]
# distance: 135
#
# Temperature: 214.63876394293726
# Neighour tour: [4, 1, 3, 2, 0]
# distance: 125
# Accepted neighbour tour: [4, 1, 3, 2, 0]
# distance: 125
#
# Temperature: 203.9068257457904
# Neighour tour: [4, 1, 3, 0, 2]
# distance: 135
# Picked neighbour tour: [4, 1, 3, 0, 2]
# distance: 135
#
# Temperature: 193.71148445850088
# Neighour tour: [2, 1, 3, 0, 4]
# distance: 150
# Picked neighbour tour: [2, 1, 3, 0, 4]
# distance: 150
#
# Temperature: 184.02591023557582
# Neighour tour: [2, 4, 3, 0, 1]
# distance: 165
# Picked neighbour tour: [2, 4, 3, 0, 1]
# distance: 165
#
# Temperature: 174.82461472379703
# Neighour tour: [3, 4, 2, 0, 1]
# distance: 150
# Accepted neighbour tour: [3, 4, 2, 0, 1]
# distance: 150
#
# Temperature: 166.08338398760716
# Neighour tour: [1, 4, 2, 0, 3]
# distance: 135
# Accepted neighbour tour: [1, 4, 2, 0, 3]
# distance: 135
#
# Temperature: 157.7792147882268
# Neighour tour: [2, 4, 1, 0, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 1, 0, 3]
# distance: 135
#
# Temperature: 149.89025404881545
# Neighour tour: [2, 3, 1, 0, 4]
# distance: 135
# Picked neighbour tour: [2, 3, 1, 0, 4]
# distance: 135
#
# Temperature: 142.39574134637468
# Neighour tour: [2, 3, 4, 0, 1]
# distance: 155
# Picked neighbour tour: [2, 3, 4, 0, 1]
# distance: 155
#
# Temperature: 135.27595427905592
# Neighour tour: [2, 0, 4, 3, 1]
# distance: 155
# Picked neighbour tour: [2, 0, 4, 3, 1]
# distance: 155
#
# Temperature: 128.5121565651031
# Neighour tour: [2, 0, 3, 4, 1]
# distance: 155
# Picked neighbour tour: [2, 0, 3, 4, 1]
# distance: 155
#
# Temperature: 122.08654873684794
# Neighour tour: [0, 2, 3, 4, 1]
# distance: 140
# Accepted neighbour tour: [0, 2, 3, 4, 1]
# distance: 140
#
# Temperature: 115.98222130000555
# Neighour tour: [4, 2, 3, 0, 1]
# distance: 135
# Accepted neighbour tour: [4, 2, 3, 0, 1]
# distance: 135
#
# Temperature: 110.18311023500526
# Neighour tour: [4, 2, 1, 0, 3]
# distance: 165
# Picked neighbour tour: [4, 2, 1, 0, 3]
# distance: 165
#
# Temperature: 104.673954723255
# Neighour tour: [3, 2, 1, 0, 4]
# distance: 155
# Accepted neighbour tour: [3, 2, 1, 0, 4]
# distance: 155
#
# Temperature: 99.44025698709224
# Neighour tour: [0, 2, 1, 3, 4]
# distance: 155
# Picked neighbour tour: [0, 2, 1, 3, 4]
# distance: 155
#
# Temperature: 94.46824413773763
# Neighour tour: [1, 2, 0, 3, 4]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 3, 4]
# distance: 155
#
# Temperature: 89.74483193085074
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 85.25759033430819
# Neighour tour: [1, 4, 0, 2, 3]
# distance: 125
# Accepted neighbour tour: [1, 4, 0, 2, 3]
# distance: 125
#
# Temperature: 80.99471081759278
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 76.94497527671314
# Neighour tour: [2, 4, 1, 0, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 1, 0, 3]
# distance: 135
#
# Temperature: 73.09772651287747
# Neighour tour: [2, 4, 1, 3, 0]
# distance: 135
# Picked neighbour tour: [2, 4, 1, 3, 0]
# distance: 135
#
# Temperature: 69.4428401872336
# Neighour tour: [2, 4, 3, 1, 0]
# distance: 150
# Picked neighbour tour: [2, 4, 3, 1, 0]
# distance: 150
#
# Temperature: 65.97069817787191
# Neighour tour: [0, 4, 3, 1, 2]
# distance: 155
# Picked neighbour tour: [0, 4, 3, 1, 2]
# distance: 155
#
# Temperature: 62.67216326897831
# Neighour tour: [0, 2, 3, 1, 4]
# distance: 125
# Accepted neighbour tour: [0, 2, 3, 1, 4]
# distance: 125
#
# Temperature: 59.53855510552939
# Neighour tour: [4, 2, 3, 1, 0]
# distance: 135
# Picked neighbour tour: [4, 2, 3, 1, 0]
# distance: 135
#
# Temperature: 56.56162735025292
# Neighour tour: [1, 2, 3, 4, 0]
# distance: 155
# Picked neighbour tour: [1, 2, 3, 4, 0]
# distance: 155
#
# Temperature: 53.733545982740274
# Neighour tour: [4, 2, 1, 3, 0]
# distance: 150
# Picked neighbour tour: [4, 2, 1, 3, 0]
# distance: 150
#
# Temperature: 51.04686868360326
# Neighour tour: [1, 2, 4, 3, 0]
# distance: 165
# Picked neighbour tour: [1, 2, 4, 3, 0]
# distance: 165
#
# Temperature: 48.49452524942309
# Neighour tour: [2, 1, 4, 3, 0]
# distance: 155
# Accepted neighbour tour: [2, 1, 4, 3, 0]
# distance: 155
#
# Temperature: 46.06979898695194
# Neighour tour: [2, 4, 1, 3, 0]
# distance: 135
# Accepted neighbour tour: [2, 4, 1, 3, 0]
# distance: 135
#
# Temperature: 43.76630903760434
# Neighour tour: [2, 4, 3, 1, 0]
# distance: 150
# Picked neighbour tour: [2, 4, 3, 1, 0]
# distance: 150
#
# Temperature: 41.577993585724116
# Neighour tour: [2, 3, 4, 1, 0]
# distance: 140
# Accepted neighbour tour: [2, 3, 4, 1, 0]
# distance: 140
#
# Temperature: 39.499093906437906
# Neighour tour: [2, 3, 4, 0, 1]
# distance: 155
# Picked neighbour tour: [2, 3, 4, 0, 1]
# distance: 155
#
# Temperature: 37.52413921111601
# Neighour tour: [2, 4, 3, 0, 1]
# distance: 165
# Picked neighbour tour: [2, 4, 3, 0, 1]
# distance: 165
#
# Temperature: 35.6479322505602
# Neighour tour: [4, 2, 3, 0, 1]
# distance: 135
# Accepted neighbour tour: [4, 2, 3, 0, 1]
# distance: 135
#
# Temperature: 33.86553563803219
# Neighour tour: [1, 2, 3, 0, 4]
# distance: 140
# Picked neighbour tour: [1, 2, 3, 0, 4]
# distance: 140
#
# Temperature: 32.17225885613058
# Neighour tour: [1, 3, 2, 0, 4]
# distance: 125
# Accepted neighbour tour: [1, 3, 2, 0, 4]
# distance: 125
#
# Temperature: 30.563645913324052
# Neighour tour: [1, 0, 2, 3, 4]
# distance: 140
# Picked neighbour tour: [1, 0, 2, 3, 4]
# distance: 140
#
# Temperature: 29.035463617657847
# Neighour tour: [1, 2, 0, 3, 4]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 3, 4]
# distance: 155
#
# Temperature: 27.583690436774955
# Neighour tour: [1, 2, 3, 0, 4]
# distance: 140
# Accepted neighbour tour: [1, 2, 3, 0, 4]
# distance: 140
#
# Temperature: 26.204505914936206
# Neighour tour: [1, 2, 3, 4, 0]
# distance: 155
# Picked neighbour tour: [1, 2, 3, 4, 0]
# distance: 155
#
# Temperature: 24.894280619189395
# Neighour tour: [1, 2, 3, 4, 0]
# distance: 155
# Picked neighbour tour: [1, 2, 3, 4, 0]
# distance: 155
#
# Temperature: 23.649566588229924
# Neighour tour: [0, 2, 3, 1, 4]
# distance: 125
# Accepted neighbour tour: [0, 2, 3, 1, 4]
# distance: 125
#
# Temperature: 22.467088258818425
# Neighour tour: [0, 2, 4, 1, 3]
# distance: 135
# Picked neighbour tour: [0, 2, 4, 1, 3]
# distance: 135
#
# Temperature: 21.3437338458775
# Neighour tour: [2, 0, 4, 1, 3]
# distance: 125
# Accepted neighbour tour: [2, 0, 4, 1, 3]
# distance: 125
#
# Temperature: 20.276547153583625
# Neighour tour: [4, 0, 2, 1, 3]
# distance: 155
# Picked neighbour tour: [4, 0, 2, 1, 3]
# distance: 155
#
# Temperature: 19.26271979590444
# Neighour tour: [0, 2, 4, 1, 3]
# distance: 135
# Picked neighbour tour: [0, 2, 4, 1, 3]
# distance: 135
#
# Temperature: 18.29958380610922
# Neighour tour: [0, 2, 3, 1, 4]
# distance: 125
# Accepted neighbour tour: [0, 2, 3, 1, 4]
# distance: 125
#
# Temperature: 17.384604615803756
# Neighour tour: [3, 2, 0, 1, 4]
# distance: 140
# Picked neighbour tour: [3, 2, 0, 1, 4]
# distance: 140
#
# Temperature: 16.51537438501357
# Neighour tour: [3, 2, 0, 4, 1]
# distance: 125
# Accepted neighbour tour: [3, 2, 0, 4, 1]
# distance: 125
#
# Temperature: 15.68960566576289
# Neighour tour: [0, 2, 3, 4, 1]
# distance: 140
# Picked neighbour tour: [0, 2, 3, 4, 1]
# distance: 140
#
# Temperature: 14.905125382474745
# Neighour tour: [3, 2, 0, 1, 4]
# distance: 140
# Picked neighbour tour: [3, 2, 0, 1, 4]
# distance: 140
#
# Temperature: 14.159869113351007
# Neighour tour: [4, 2, 0, 1, 3]
# distance: 150
# Picked neighbour tour: [4, 2, 0, 1, 3]
# distance: 150
#
# Temperature: 13.451875657683456
# Neighour tour: [4, 3, 0, 1, 2]
# distance: 165
# Picked neighbour tour: [4, 3, 0, 1, 2]
# distance: 165
#
# Temperature: 12.779281874799283
# Neighour tour: [4, 0, 3, 1, 2]
# distance: 150
# Accepted neighbour tour: [4, 0, 3, 1, 2]
# distance: 150
#
# Temperature: 12.140317781059318
# Neighour tour: [4, 3, 0, 1, 2]
# distance: 165
# Picked neighbour tour: [4, 3, 0, 1, 2]
# distance: 165
#
# Temperature: 11.533301892006351
# Neighour tour: [4, 0, 3, 2, 1]
# distance: 140
# Accepted neighbour tour: [4, 0, 3, 2, 1]
# distance: 140
#
# Temperature: 10.956636797406032
# Neighour tour: [0, 4, 3, 2, 1]
# distance: 155
# Picked neighbour tour: [0, 4, 3, 2, 1]
# distance: 155
#
# Temperature: 10.40880495753573
# Neighour tour: [4, 0, 2, 3, 1]
# distance: 125
# Accepted neighbour tour: [4, 0, 2, 3, 1]
# distance: 125
#
# Temperature: 9.888364709658944
# Neighour tour: [4, 0, 3, 2, 1]
# distance: 140
# Picked neighbour tour: [4, 0, 3, 2, 1]
# distance: 140
#
# Temperature: 9.393946474175996
# Neighour tour: [4, 1, 2, 3, 0]
# distance: 140
# Picked neighbour tour: [4, 1, 2, 3, 0]
# distance: 140
#
# Temperature: 8.924249150467196
# Neighour tour: [1, 4, 2, 3, 0]
# distance: 135
# Accepted neighbour tour: [1, 4, 2, 3, 0]
# distance: 135
#
# Temperature: 8.478036692943835
# Neighour tour: [4, 1, 2, 3, 0]
# distance: 140
# Picked neighbour tour: [4, 1, 2, 3, 0]
# distance: 140
#
# Temperature: 8.054134858296642
# Neighour tour: [1, 4, 2, 0, 3]
# distance: 135
# Picked neighbour tour: [1, 4, 2, 0, 3]
# distance: 135
#
# Temperature: 7.65142811538181
# Neighour tour: [1, 4, 3, 0, 2]
# distance: 155
# Picked neighbour tour: [1, 4, 3, 0, 2]
# distance: 155
#
# Temperature: 7.268856709612719
# Neighour tour: [0, 4, 2, 1, 3]
# distance: 150
# Picked neighbour tour: [0, 4, 2, 1, 3]
# distance: 150
#
# Temperature: 6.9054138741320825
# Neighour tour: [1, 0, 2, 4, 3]
# distance: 150
# Picked neighbour tour: [1, 0, 2, 4, 3]
# distance: 150
#
# Temperature: 6.560143180425478
# Neighour tour: [1, 3, 2, 0, 4]
# distance: 125
# Accepted neighbour tour: [1, 3, 2, 0, 4]
# distance: 125
#
# Temperature: 6.232136021404204
# Neighour tour: [4, 3, 2, 0, 1]
# distance: 140
# Picked neighbour tour: [4, 3, 2, 0, 1]
# distance: 140
#
# Temperature: 5.920529220333994
# Neighour tour: [4, 3, 2, 0, 1]
# distance: 140
# Picked neighbour tour: [4, 3, 2, 0, 1]
# distance: 140
#
# Temperature: 5.624502759317294
# Neighour tour: [1, 4, 2, 0, 3]
# distance: 135
# Picked neighbour tour: [1, 4, 2, 0, 3]
# distance: 135
#
# Temperature: 5.3432776213514295
# Neighour tour: [1, 4, 0, 2, 3]
# distance: 125
# Accepted neighbour tour: [1, 4, 0, 2, 3]
# distance: 125
#
# Temperature: 5.076113740283858
# Neighour tour: [1, 0, 4, 2, 3]
# distance: 135
# Picked neighbour tour: [1, 0, 4, 2, 3]
# distance: 135
#
# Temperature: 4.822308053269665
# Neighour tour: [1, 4, 0, 3, 2]
# distance: 140
# Picked neighbour tour: [1, 4, 0, 3, 2]
# distance: 140
#
# Temperature: 4.581192650606181
# Neighour tour: [0, 4, 1, 2, 3]
# distance: 140
# Picked neighbour tour: [0, 4, 1, 2, 3]
# distance: 140
#
# Temperature: 4.352133018075872
# Neighour tour: [0, 4, 1, 2, 3]
# distance: 140
# Picked neighbour tour: [0, 4, 1, 2, 3]
# distance: 140
#
# Temperature: 4.134526367172078
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 3.9278000488134737
# Neighour tour: [1, 3, 0, 2, 4]
# distance: 135
# Picked neighbour tour: [1, 3, 0, 2, 4]
# distance: 135
#
# Temperature: 3.7314100463727997
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 3.5448395440541596
# Neighour tour: [4, 1, 0, 2, 3]
# distance: 140
# Picked neighbour tour: [4, 1, 0, 2, 3]
# distance: 140
#
# Temperature: 3.3675975668514515
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 3.1992176885088788
# Neighour tour: [1, 3, 0, 2, 4]
# distance: 135
# Picked neighbour tour: [1, 3, 0, 2, 4]
# distance: 135
#
# Temperature: 3.039256804083435
# Neighour tour: [1, 4, 0, 3, 2]
# distance: 140
# Picked neighbour tour: [1, 4, 0, 3, 2]
# distance: 140
#
# Temperature: 2.887293963879263
# Neighour tour: [1, 3, 0, 2, 4]
# distance: 135
# Picked neighbour tour: [1, 3, 0, 2, 4]
# distance: 135
#
# Temperature: 2.7429292656852997
# Neighour tour: [1, 4, 0, 3, 2]
# distance: 140
# Picked neighbour tour: [1, 4, 0, 3, 2]
# distance: 140
#
# Temperature: 2.6057828024010345
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 2.4754936622809827
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 2.3517189791669333
# Neighour tour: [1, 4, 0, 3, 2]
# distance: 140
# Picked neighbour tour: [1, 4, 0, 3, 2]
# distance: 140
#
# Temperature: 2.2341330302085867
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 2.122426378698157
# Neighour tour: [4, 1, 0, 2, 3]
# distance: 140
# Picked neighbour tour: [4, 1, 0, 2, 3]
# distance: 140
#
# Temperature: 2.016305059763249
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 1.9154898067750865
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 1.819715316436332
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 1.7287295506145153
# Neighour tour: [1, 4, 0, 3, 2]
# distance: 140
# Picked neighbour tour: [1, 4, 0, 3, 2]
# distance: 140
#
# Temperature: 1.6422930730837895
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 1.5601784194296
# Neighour tour: [1, 3, 0, 2, 4]
# distance: 135
# Picked neighbour tour: [1, 3, 0, 2, 4]
# distance: 135
#
# Temperature: 1.48216949845812
# Neighour tour: [0, 4, 1, 2, 3]
# distance: 140
# Picked neighbour tour: [0, 4, 1, 2, 3]
# distance: 140
#
# Temperature: 1.408061023535214
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 1.3376579723584532
# Neighour tour: [1, 4, 2, 0, 3]
# distance: 135
# Picked neighbour tour: [1, 4, 2, 0, 3]
# distance: 135
#
# Temperature: 1.2707750737405306
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 1.207236320053504
# Neighour tour: [1, 0, 4, 2, 3]
# distance: 135
# Picked neighbour tour: [1, 0, 4, 2, 3]
# distance: 135
#
# Temperature: 1.1468745040508286
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 1.089530778848287
# Neighour tour: [1, 4, 2, 0, 3]
# distance: 135
# Picked neighbour tour: [1, 4, 2, 0, 3]
# distance: 135
#
# Temperature: 1.0350542399058726
# Neighour tour: [4, 1, 0, 2, 3]
# distance: 140
# Picked neighbour tour: [4, 1, 0, 2, 3]
# distance: 140
#
# Temperature: 0.983301527910579
# Neighour tour: [1, 0, 4, 2, 3]
# distance: 135
# Picked neighbour tour: [1, 0, 4, 2, 3]
# distance: 135
#
# Temperature: 0.93413645151505
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 0.8874296289392974
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 0.8430581474923325
# Neighour tour: [0, 4, 1, 2, 3]
# distance: 140
# Picked neighbour tour: [0, 4, 1, 2, 3]
# distance: 140
#
# Temperature: 0.8009052401177159
# Neighour tour: [4, 1, 0, 2, 3]
# distance: 140
# Picked neighbour tour: [4, 1, 0, 2, 3]
# distance: 140
#
# Temperature: 0.76085997811183
# Neighour tour: [4, 1, 0, 2, 3]
# distance: 140
# Picked neighbour tour: [4, 1, 0, 2, 3]
# distance: 140
#
# Temperature: 0.7228169792062386
# Neighour tour: [1, 0, 4, 2, 3]
# distance: 135
# Picked neighbour tour: [1, 0, 4, 2, 3]
# distance: 135
#
# Temperature: 0.6866761302459266
# Neighour tour: [1, 0, 4, 2, 3]
# distance: 135
# Picked neighbour tour: [1, 0, 4, 2, 3]
# distance: 135
#
# Temperature: 0.6523423237336302
# Neighour tour: [1, 4, 0, 3, 2]
# distance: 140
# Picked neighbour tour: [1, 4, 0, 3, 2]
# distance: 140
#
# Temperature: 0.6197252075469487
# Neighour tour: [1, 4, 2, 0, 3]
# distance: 135
# Picked neighbour tour: [1, 4, 2, 0, 3]
# distance: 135
#
# Temperature: 0.5887389471696013
# Neighour tour: [4, 1, 0, 2, 3]
# distance: 140
# Picked neighbour tour: [4, 1, 0, 2, 3]
# distance: 140
#
# Temperature: 0.5593019998111212
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 0.5313368998205651
# Neighour tour: [1, 3, 0, 2, 4]
# distance: 135
# Picked neighbour tour: [1, 3, 0, 2, 4]
# distance: 135
#
# Temperature: 0.5047700548295369
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 0.47953155208806
# Neighour tour: [0, 4, 1, 2, 3]
# distance: 140
# Picked neighbour tour: [0, 4, 1, 2, 3]
# distance: 140
#
# Temperature: 0.45555497448365695
# Neighour tour: [1, 4, 2, 0, 3]
# distance: 135
# Picked neighbour tour: [1, 4, 2, 0, 3]
# distance: 135
#
# Temperature: 0.4327772257594741
# Neighour tour: [4, 1, 0, 2, 3]
# distance: 140
# Picked neighbour tour: [4, 1, 0, 2, 3]
# distance: 140
#
# Temperature: 0.4111383644715004
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 0.39058144624792535
# Neighour tour: [4, 1, 0, 2, 3]
# distance: 140
# Picked neighbour tour: [4, 1, 0, 2, 3]
# distance: 140
#
# Temperature: 0.37105237393552903
# Neighour tour: [1, 0, 4, 2, 3]
# distance: 135
# Picked neighbour tour: [1, 0, 4, 2, 3]
# distance: 135
#
# Temperature: 0.35249975523875254
# Neighour tour: [4, 1, 0, 2, 3]
# distance: 140
# Picked neighbour tour: [4, 1, 0, 2, 3]
# distance: 140
#
# Temperature: 0.3348747674768149
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 0.31813102910297414
# Neighour tour: [4, 1, 0, 2, 3]
# distance: 140
# Picked neighbour tour: [4, 1, 0, 2, 3]
# distance: 140
#
# Temperature: 0.3022244776478254
# Neighour tour: [0, 4, 1, 2, 3]
# distance: 140
# Picked neighbour tour: [0, 4, 1, 2, 3]
# distance: 140
#
# Temperature: 0.2871132537654341
# Neighour tour: [1, 3, 0, 2, 4]
# distance: 135
# Picked neighbour tour: [1, 3, 0, 2, 4]
# distance: 135
#
# Temperature: 0.2727575910771624
# Neighour tour: [1, 4, 0, 3, 2]
# distance: 140
# Picked neighbour tour: [1, 4, 0, 3, 2]
# distance: 140
#
# Temperature: 0.25911971152330426
# Neighour tour: [1, 0, 4, 2, 3]
# distance: 135
# Picked neighbour tour: [1, 0, 4, 2, 3]
# distance: 135
#
# Temperature: 0.24616372594713903
# Neighour tour: [1, 4, 2, 0, 3]
# distance: 135
# Picked neighbour tour: [1, 4, 2, 0, 3]
# distance: 135
#
# Temperature: 0.23385553964978206
# Neighour tour: [1, 4, 0, 3, 2]
# distance: 140
# Picked neighbour tour: [1, 4, 0, 3, 2]
# distance: 140
#
# Temperature: 0.22216276266729296
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 0.2110546245339283
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 0.20050189330723187
# Neighour tour: [1, 0, 4, 2, 3]
# distance: 135
# Picked neighbour tour: [1, 0, 4, 2, 3]
# distance: 135
#
# Temperature: 0.19047679864187025
# Neighour tour: [1, 3, 0, 2, 4]
# distance: 135
# Picked neighbour tour: [1, 3, 0, 2, 4]
# distance: 135
#
# Temperature: 0.18095295870977673
# Neighour tour: [4, 1, 0, 2, 3]
# distance: 140
# Picked neighbour tour: [4, 1, 0, 2, 3]
# distance: 140
#
# Temperature: 0.1719053107742879
# Neighour tour: [1, 4, 0, 3, 2]
# distance: 140
# Picked neighbour tour: [1, 4, 0, 3, 2]
# distance: 140
#
# Temperature: 0.1633100452355735
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 0.15514454297379482
# Neighour tour: [1, 3, 0, 2, 4]
# distance: 135
# Picked neighbour tour: [1, 3, 0, 2, 4]
# distance: 135
#
# Temperature: 0.14738731582510506
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 0.1400179500338498
# Neighour tour: [1, 3, 0, 2, 4]
# distance: 135
# Picked neighbour tour: [1, 3, 0, 2, 4]
# distance: 135
#
# Temperature: 0.1330170525321573
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 0.12636619990554943
# Neighour tour: [4, 1, 0, 2, 3]
# distance: 140
# Picked neighbour tour: [4, 1, 0, 2, 3]
# distance: 140
#
# Temperature: 0.12004788991027195
# Neighour tour: [0, 4, 1, 2, 3]
# distance: 140
# Picked neighbour tour: [0, 4, 1, 2, 3]
# distance: 140
#
# Temperature: 0.11404549541475835
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 0.10834322064402042
# Neighour tour: [4, 1, 0, 2, 3]
# distance: 140
# Picked neighbour tour: [4, 1, 0, 2, 3]
# distance: 140
#
# Temperature: 0.1029260596118194
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 0.09777975663122843
# Neighour tour: [1, 4, 0, 3, 2]
# distance: 140
# Picked neighbour tour: [1, 4, 0, 3, 2]
# distance: 140
#
# Temperature: 0.092890768799667
# Neighour tour: [1, 4, 2, 0, 3]
# distance: 135
# Picked neighbour tour: [1, 4, 2, 0, 3]
# distance: 135
#
# Temperature: 0.08824623035968364
# Neighour tour: [1, 4, 2, 0, 3]
# distance: 135
# Picked neighbour tour: [1, 4, 2, 0, 3]
# distance: 135
#
# Temperature: 0.08383391884169945
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 0.07964222289961448
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 0.07566011175463375
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 0.07187710616690206
# Neighour tour: [0, 4, 1, 2, 3]
# distance: 140
# Picked neighbour tour: [0, 4, 1, 2, 3]
# distance: 140
#
# Temperature: 0.06828325085855695
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 0.0648690883156291
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 0.06162563389984764
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 0.05854435220485526
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 0.05561713459461249
# Neighour tour: [1, 3, 0, 2, 4]
# distance: 135
# Picked neighbour tour: [1, 3, 0, 2, 4]
# distance: 135
#
# Temperature: 0.05283627786488186
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 0.050194463971637765
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 0.04768474077305587
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 0.04530050373440308
# Neighour tour: [0, 4, 1, 2, 3]
# distance: 140
# Picked neighbour tour: [0, 4, 1, 2, 3]
# distance: 140
#
# Temperature: 0.04303547854768292
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 0.04088370462029877
# Neighour tour: [1, 4, 0, 3, 2]
# distance: 140
# Picked neighbour tour: [1, 4, 0, 3, 2]
# distance: 140
#
# Temperature: 0.03883951938928383
# Neighour tour: [1, 4, 0, 3, 2]
# distance: 140
# Picked neighbour tour: [1, 4, 0, 3, 2]
# distance: 140
#
# Temperature: 0.036897543419819635
# Neighour tour: [1, 4, 2, 0, 3]
# distance: 135
# Picked neighbour tour: [1, 4, 2, 0, 3]
# distance: 135
#
# Temperature: 0.035052666248828655
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 0.03330003293638722
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 0.03163503128956786
# Neighour tour: [1, 0, 4, 2, 3]
# distance: 135
# Picked neighbour tour: [1, 0, 4, 2, 3]
# distance: 135
#
# Temperature: 0.030053279725089463
# Neighour tour: [1, 4, 0, 3, 2]
# distance: 140
# Picked neighbour tour: [1, 4, 0, 3, 2]
# distance: 140
#
# Temperature: 0.028550615738834988
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 0.027123084951893237
# Neighour tour: [1, 4, 0, 3, 2]
# distance: 140
# Picked neighbour tour: [1, 4, 0, 3, 2]
# distance: 140
#
# Temperature: 0.025766930704298575
# Neighour tour: [0, 4, 1, 2, 3]
# distance: 140
# Picked neighbour tour: [0, 4, 1, 2, 3]
# distance: 140
#
# Temperature: 0.024478584169083644
# Neighour tour: [0, 4, 1, 2, 3]
# distance: 140
# Picked neighbour tour: [0, 4, 1, 2, 3]
# distance: 140
#
# Temperature: 0.02325465496062946
# Neighour tour: [1, 3, 0, 2, 4]
# distance: 135
# Picked neighbour tour: [1, 3, 0, 2, 4]
# distance: 135
#
# Temperature: 0.022091922212597988
# Neighour tour: [1, 3, 0, 2, 4]
# distance: 135
# Picked neighbour tour: [1, 3, 0, 2, 4]
# distance: 135
#
# Temperature: 0.020987326101968087
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 0.019937959796869683
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 0.018941061807026198
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 0.01799400871667489
# Neighour tour: [1, 0, 4, 2, 3]
# distance: 135
# Picked neighbour tour: [1, 0, 4, 2, 3]
# distance: 135
#
# Temperature: 0.017094308280841145
# Neighour tour: [1, 0, 4, 2, 3]
# distance: 135
# Picked neighbour tour: [1, 0, 4, 2, 3]
# distance: 135
#
# Temperature: 0.016239592866799088
# Neighour tour: [4, 1, 0, 2, 3]
# distance: 140
# Picked neighbour tour: [4, 1, 0, 2, 3]
# distance: 140
#
# Temperature: 0.015427613223459133
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 0.014656232562286176
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 0.013923420934171867
# Neighour tour: [1, 0, 4, 2, 3]
# distance: 135
# Picked neighbour tour: [1, 0, 4, 2, 3]
# distance: 135
#
# Temperature: 0.013227249887463273
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 0.012565887393090109
# Neighour tour: [4, 1, 0, 2, 3]
# distance: 140
# Picked neighbour tour: [4, 1, 0, 2, 3]
# distance: 140
#
# Temperature: 0.011937593023435602
# Neighour tour: [1, 4, 2, 0, 3]
# distance: 135
# Picked neighbour tour: [1, 4, 2, 0, 3]
# distance: 135
#
# Temperature: 0.011340713372263821
# Neighour tour: [1, 3, 0, 2, 4]
# distance: 135
# Picked neighbour tour: [1, 3, 0, 2, 4]
# distance: 135
#
# Temperature: 0.01077367770365063
# Neighour tour: [1, 0, 4, 2, 3]
# distance: 135
# Picked neighbour tour: [1, 0, 4, 2, 3]
# distance: 135
#
# Temperature: 0.010234993818468098
# Neighour tour: [0, 4, 1, 2, 3]
# distance: 140
# Picked neighbour tour: [0, 4, 1, 2, 3]
# distance: 140
#
# Temperature: 0.009723244127544692
# Neighour tour: [1, 0, 4, 2, 3]
# distance: 135
# Picked neighbour tour: [1, 0, 4, 2, 3]
# distance: 135
#
# Temperature: 0.009237081921167458
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 0.008775227825109085
# Neighour tour: [1, 0, 4, 2, 3]
# distance: 135
# Picked neighbour tour: [1, 0, 4, 2, 3]
# distance: 135
#
# Temperature: 0.00833646643385363
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 0.00791964311216095
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 0.007523660956552902
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 0.007147477908725257
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 0.006790104013288993
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 0.006450598812624543
# Neighour tour: [1, 4, 2, 0, 3]
# distance: 135
# Picked neighbour tour: [1, 4, 2, 0, 3]
# distance: 135
#
# Temperature: 0.006128068871993316
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 0.00582166542839365
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 0.005530582156973967
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 0.005254053049125268
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 0.004991350396669004
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 0.004741782876835554
# Neighour tour: [1, 4, 0, 3, 2]
# distance: 140
# Picked neighbour tour: [1, 4, 0, 3, 2]
# distance: 140
#
# Temperature: 0.004504693732993776
# Neighour tour: [1, 0, 4, 2, 3]
# distance: 135
# Picked neighbour tour: [1, 0, 4, 2, 3]
# distance: 135
#
# Temperature: 0.004279459046344087
# Neighour tour: [4, 1, 0, 2, 3]
# distance: 140
# Picked neighbour tour: [4, 1, 0, 2, 3]
# distance: 140
#
# Temperature: 0.004065486094026882
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 0.0038622117893255376
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 0.0036691011998592604
# Neighour tour: [1, 4, 2, 0, 3]
# distance: 135
# Picked neighbour tour: [1, 4, 2, 0, 3]
# distance: 135
#
# Temperature: 0.003485646139866297
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 0.0033113638328729823
# Neighour tour: [1, 4, 0, 3, 2]
# distance: 140
# Picked neighbour tour: [1, 4, 0, 3, 2]
# distance: 140
#
# Temperature: 0.003145795641229333
# Neighour tour: [1, 3, 0, 2, 4]
# distance: 135
# Picked neighbour tour: [1, 3, 0, 2, 4]
# distance: 135
#
# Temperature: 0.002988505859167866
# Neighour tour: [1, 0, 4, 2, 3]
# distance: 135
# Picked neighbour tour: [1, 0, 4, 2, 3]
# distance: 135
#
# Temperature: 0.0028390805662094724
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 0.0026971265378989986
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 0.0025622702110040486
# Neighour tour: [1, 4, 2, 0, 3]
# distance: 135
# Picked neighbour tour: [1, 4, 2, 0, 3]
# distance: 135
#
# Temperature: 0.0024341567004538462
# Neighour tour: [0, 4, 1, 2, 3]
# distance: 140
# Picked neighbour tour: [0, 4, 1, 2, 3]
# distance: 140
#
# Temperature: 0.0023124488654311538
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 0.002196826422159596
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 0.0020869851010516163
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 0.0019826358459990355
# Neighour tour: [0, 4, 1, 2, 3]
# distance: 140
# Picked neighbour tour: [0, 4, 1, 2, 3]
# distance: 140
#
# Temperature: 0.0018835040536990836
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 0.0017893288510141294
# Neighour tour: [1, 4, 0, 3, 2]
# distance: 140
# Picked neighbour tour: [1, 4, 0, 3, 2]
# distance: 140
#
# Temperature: 0.0016998624084634227
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 0.0016148692880402515
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 0.0015341258236382389
# Neighour tour: [1, 4, 2, 0, 3]
# distance: 135
# Picked neighbour tour: [1, 4, 2, 0, 3]
# distance: 135
#
# Temperature: 0.0014574195324563268
# Neighour tour: [1, 4, 0, 3, 2]
# distance: 140
# Picked neighbour tour: [1, 4, 0, 3, 2]
# distance: 140
#
# Temperature: 0.0013845485558335105
# Neighour tour: [1, 4, 2, 0, 3]
# distance: 135
# Picked neighbour tour: [1, 4, 2, 0, 3]
# distance: 135
#
# Temperature: 0.0013153211280418349
# Neighour tour: [1, 3, 0, 2, 4]
# distance: 135
# Picked neighbour tour: [1, 3, 0, 2, 4]
# distance: 135
#
# Temperature: 0.001249555071639743
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 0.0011870773180577558
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 0.001127723452154868
# Neighour tour: [1, 3, 0, 2, 4]
# distance: 135
# Picked neighbour tour: [1, 3, 0, 2, 4]
# distance: 135
#
# Temperature: 0.0010713372795471245
# Neighour tour: [0, 4, 1, 2, 3]
# distance: 140
# Picked neighbour tour: [0, 4, 1, 2, 3]
# distance: 140
#
# Temperature: 0.0010177704155697681
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 0.0009668818947912796
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 0.0009185378000517156
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 0.0008726109100491298
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 0.0008289803645466733
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 0.0007875313463193396
# Neighour tour: [1, 4, 0, 3, 2]
# distance: 140
# Picked neighbour tour: [1, 4, 0, 3, 2]
# distance: 140
#
# Temperature: 0.0007481547790033726
# Neighour tour: [1, 4, 0, 3, 2]
# distance: 140
# Picked neighbour tour: [1, 4, 0, 3, 2]
# distance: 140
#
# Temperature: 0.0007107470400532039
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 0.0006752096880505437
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 0.0006414492036480165
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 0.0006093767434656157
# Neighour tour: [4, 1, 0, 2, 3]
# distance: 140
# Picked neighbour tour: [4, 1, 0, 2, 3]
# distance: 140
#
# Temperature: 0.0005789079062923348
# Neighour tour: [1, 4, 2, 0, 3]
# distance: 135
# Picked neighbour tour: [1, 4, 2, 0, 3]
# distance: 135
#
# Temperature: 0.000549962510977718
# Neighour tour: [1, 4, 2, 0, 3]
# distance: 135
# Picked neighbour tour: [1, 4, 2, 0, 3]
# distance: 135
#
# Temperature: 0.0005224643854288321
# Neighour tour: [0, 4, 1, 2, 3]
# distance: 140
# Picked neighbour tour: [0, 4, 1, 2, 3]
# distance: 140
#
# Temperature: 0.0004963411661573904
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 0.0004715241078495209
# Neighour tour: [4, 1, 0, 2, 3]
# distance: 140
# Picked neighbour tour: [4, 1, 0, 2, 3]
# distance: 140
#
# Temperature: 0.00044794790245704483
# Neighour tour: [4, 1, 0, 2, 3]
# distance: 140
# Picked neighbour tour: [4, 1, 0, 2, 3]
# distance: 140
#
# Temperature: 0.0004255505073341926
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 0.0004042729819674829
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 0.00038405933286910876
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 0.0003648563662256533
# Neighour tour: [4, 1, 0, 2, 3]
# distance: 140
# Picked neighbour tour: [4, 1, 0, 2, 3]
# distance: 140
#
# Temperature: 0.0003466135479143706
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 0.0003292828705186521
# Neighour tour: [1, 4, 0, 3, 2]
# distance: 140
# Picked neighbour tour: [1, 4, 0, 3, 2]
# distance: 140
#
# Temperature: 0.00031281872699271947
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 0.0002971777906430835
# Neighour tour: [0, 4, 1, 2, 3]
# distance: 140
# Picked neighbour tour: [0, 4, 1, 2, 3]
# distance: 140
#
# Temperature: 0.0002823189011109293
# Neighour tour: [1, 4, 2, 0, 3]
# distance: 135
# Picked neighbour tour: [1, 4, 2, 0, 3]
# distance: 135
#
# Temperature: 0.0002682029560553828
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 0.00025479280825261365
# Neighour tour: [1, 3, 0, 2, 4]
# distance: 135
# Picked neighbour tour: [1, 3, 0, 2, 4]
# distance: 135
#
# Temperature: 0.00024205316783998295
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 0.0002299505094479838
# Neighour tour: [1, 0, 4, 2, 3]
# distance: 135
# Picked neighbour tour: [1, 0, 4, 2, 3]
# distance: 135
#
# Temperature: 0.0002184529839755846
# Neighour tour: [4, 1, 0, 2, 3]
# distance: 140
# Picked neighbour tour: [4, 1, 0, 2, 3]
# distance: 140
#
# Temperature: 0.00020753033477680536
# Neighour tour: [1, 0, 4, 2, 3]
# distance: 135
# Picked neighbour tour: [1, 0, 4, 2, 3]
# distance: 135
#
# Temperature: 0.00019715381803796507
# Neighour tour: [1, 4, 2, 0, 3]
# distance: 135
# Picked neighbour tour: [1, 4, 2, 0, 3]
# distance: 135
#
# Temperature: 0.0001872961271360668
# Neighour tour: [0, 4, 1, 2, 3]
# distance: 140
# Picked neighbour tour: [0, 4, 1, 2, 3]
# distance: 140
#
# Temperature: 0.00017793132077926346
# Neighour tour: [1, 3, 0, 2, 4]
# distance: 135
# Picked neighbour tour: [1, 3, 0, 2, 4]
# distance: 135
#
# Temperature: 0.0001690347547403003
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 0.00016058301700328529
# Neighour tour: [0, 4, 1, 2, 3]
# distance: 140
# Picked neighbour tour: [0, 4, 1, 2, 3]
# distance: 140
#
# Temperature: 0.000152553866153121
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 0.00014492617284546494
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 0.00013767986420319168
# Neighour tour: [0, 4, 1, 2, 3]
# distance: 140
# Picked neighbour tour: [0, 4, 1, 2, 3]
# distance: 140
#
# Temperature: 0.0001307958709930321
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 0.00012425607744338048
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 0.00011804327357121146
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 0.00011214110989265088
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 0.00010653405439801834
# Neighour tour: [1, 0, 4, 2, 3]
# distance: 135
# Picked neighbour tour: [1, 0, 4, 2, 3]
# distance: 135
#
# Temperature: 0.00010120735167811742
# Neighour tour: [4, 1, 0, 2, 3]
# distance: 140
# Picked neighbour tour: [4, 1, 0, 2, 3]
# distance: 140
#
# Temperature: 9.614698409421154e-05
# Neighour tour: [4, 1, 0, 2, 3]
# distance: 140
# Picked neighbour tour: [4, 1, 0, 2, 3]
# distance: 140
#
# Temperature: 9.133963488950096e-05
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 8.677265314502591e-05
# Neighour tour: [1, 4, 2, 0, 3]
# distance: 135
# Picked neighbour tour: [1, 4, 2, 0, 3]
# distance: 135
#
# Temperature: 8.243402048777461e-05
# Neighour tour: [1, 3, 0, 2, 4]
# distance: 135
# Picked neighbour tour: [1, 3, 0, 2, 4]
# distance: 135
#
# Temperature: 7.831231946338587e-05
# Neighour tour: [1, 0, 4, 2, 3]
# distance: 135
# Picked neighbour tour: [1, 0, 4, 2, 3]
# distance: 135
#
# Temperature: 7.439670349021657e-05
# Neighour tour: [1, 4, 2, 0, 3]
# distance: 135
# Picked neighbour tour: [1, 4, 2, 0, 3]
# distance: 135
#
# Temperature: 7.067686831570574e-05
# Neighour tour: [4, 1, 0, 2, 3]
# distance: 140
# Picked neighbour tour: [4, 1, 0, 2, 3]
# distance: 140
#
# Temperature: 6.714302489992045e-05
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 6.378587365492443e-05
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 6.059657997217821e-05
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 5.75667509735693e-05
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 5.468841342489083e-05
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 5.1953992753646287e-05
# Neighour tour: [1, 0, 4, 2, 3]
# distance: 135
# Picked neighbour tour: [1, 0, 4, 2, 3]
# distance: 135
#
# Temperature: 4.935629311596397e-05
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 4.688847846016577e-05
# Neighour tour: [1, 4, 0, 3, 2]
# distance: 140
# Picked neighbour tour: [1, 4, 0, 3, 2]
# distance: 140
#
# Temperature: 4.454405453715748e-05
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 4.23168518102996e-05
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 4.020100921978462e-05
# Neighour tour: [1, 4, 2, 0, 3]
# distance: 135
# Picked neighbour tour: [1, 4, 2, 0, 3]
# distance: 135
#
# Temperature: 3.819095875879539e-05
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 3.628141082085562e-05
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 3.446734027981284e-05
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 3.27439732658222e-05
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 3.110677460253109e-05
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 2.955143587240453e-05
# Neighour tour: [1, 4, 2, 0, 3]
# distance: 135
# Picked neighbour tour: [1, 4, 2, 0, 3]
# distance: 135
#
# Temperature: 2.8073864078784304e-05
# Neighour tour: [1, 4, 0, 3, 2]
# distance: 140
# Picked neighbour tour: [1, 4, 0, 3, 2]
# distance: 140
#
# Temperature: 2.6670170874845087e-05
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 2.533666233110283e-05
# Neighour tour: [1, 3, 0, 2, 4]
# distance: 135
# Picked neighbour tour: [1, 3, 0, 2, 4]
# distance: 135
#
# Temperature: 2.406982921454769e-05
# Neighour tour: [1, 3, 0, 2, 4]
# distance: 135
# Picked neighbour tour: [1, 3, 0, 2, 4]
# distance: 135
#
# Temperature: 2.2866337753820305e-05
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 2.1723020866129288e-05
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 2.0636869822822822e-05
# Neighour tour: [1, 0, 4, 2, 3]
# distance: 135
# Picked neighbour tour: [1, 0, 4, 2, 3]
# distance: 135
#
# Temperature: 1.960502633168168e-05
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 1.8624775015097596e-05
# Neighour tour: [1, 0, 4, 2, 3]
# distance: 135
# Picked neighbour tour: [1, 0, 4, 2, 3]
# distance: 135
#
# Temperature: 1.7693536264342717e-05
# Neighour tour: [1, 0, 4, 2, 3]
# distance: 135
# Picked neighbour tour: [1, 0, 4, 2, 3]
# distance: 135
#
# Temperature: 1.6808859451125582e-05
# Neighour tour: [1, 3, 0, 2, 4]
# distance: 135
# Picked neighbour tour: [1, 3, 0, 2, 4]
# distance: 135
#
# Temperature: 1.5968416478569304e-05
# Neighour tour: [1, 3, 0, 2, 4]
# distance: 135
# Picked neighbour tour: [1, 3, 0, 2, 4]
# distance: 135
#
# Temperature: 1.5169995654640838e-05
# Neighour tour: [0, 4, 1, 2, 3]
# distance: 140
# Picked neighbour tour: [0, 4, 1, 2, 3]
# distance: 140
#
# Temperature: 1.4411495871908796e-05
# Neighour tour: [1, 0, 4, 2, 3]
# distance: 135
# Picked neighbour tour: [1, 0, 4, 2, 3]
# distance: 135
#
# Temperature: 1.3690921078313355e-05
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 1.3006375024397686e-05
# Neighour tour: [1, 0, 4, 2, 3]
# distance: 135
# Picked neighbour tour: [1, 0, 4, 2, 3]
# distance: 135
#
# Temperature: 1.2356056273177802e-05
# Neighour tour: [1, 0, 4, 2, 3]
# distance: 135
# Picked neighbour tour: [1, 0, 4, 2, 3]
# distance: 135
#
# Temperature: 1.1738253459518912e-05
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 1.1151340786542966e-05
# Neighour tour: [1, 3, 0, 2, 4]
# distance: 135
# Picked neighbour tour: [1, 3, 0, 2, 4]
# distance: 135
#
# Temperature: 1.0593773747215816e-05
# Neighour tour: [1, 3, 0, 2, 4]
# distance: 135
# Picked neighbour tour: [1, 3, 0, 2, 4]
# distance: 135
#
# Temperature: 1.0064085059855026e-05
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 9.560880806862273e-06
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 9.08283676651916e-06
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 8.628694928193201e-06
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 8.19726018178354e-06
# ...
# Picked neighbour tour: [4, 1, 0, 2, 3]
# distance: 140
#
# Temperature: 3.0932656605152464e-06
# Neighour tour: [4, 1, 0, 2, 3]
# distance: 140
# Picked neighbour tour: [4, 1, 0, 2, 3]
# distance: 140
#
# Temperature: 2.938602377489484e-06
# Neighour tour: [1, 0, 4, 2, 3]
# distance: 135
# Picked neighbour tour: [1, 0, 4, 2, 3]
# distance: 135
#
# Temperature: 2.7916722586150097e-06
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 2.6520886456842592e-06
# Neighour tour: [1, 4, 2, 0, 3]
# distance: 135
# Picked neighbour tour: [1, 4, 2, 0, 3]
# distance: 135
#
# Temperature: 2.519484213400046e-06
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 2.3935100027300434e-06
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 2.273834502593541e-06
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 2.160142777463864e-06
# Neighour tour: [1, 3, 0, 2, 4]
# distance: 135
# Picked neighbour tour: [1, 3, 0, 2, 4]
# distance: 135
#
# Temperature: 2.0521356385906705e-06
# Neighour tour: [1, 4, 0, 3, 2]
# distance: 140
# Picked neighbour tour: [1, 4, 0, 3, 2]
# distance: 140
#
# Temperature: 1.949528856661137e-06
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 1.85205241382808e-06
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 1.759449793136676e-06
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 1.671477303479842e-06
# Neighour tour: [0, 4, 1, 2, 3]
# distance: 140
# Picked neighbour tour: [0, 4, 1, 2, 3]
# distance: 140
#
# Temperature: 1.5879034383058499e-06
# Neighour tour: [1, 4, 0, 3, 2]
# distance: 140
# Picked neighbour tour: [1, 4, 0, 3, 2]
# distance: 140
#
# Temperature: 1.5085082663905573e-06
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 1.4330828530710295e-06
# Neighour tour: [1, 0, 4, 2, 3]
# distance: 135
# Picked neighbour tour: [1, 0, 4, 2, 3]
# distance: 135
#
# Temperature: 1.361428710417478e-06
# Neighour tour: [1, 0, 4, 2, 3]
# distance: 135
# Picked neighbour tour: [1, 0, 4, 2, 3]
# distance: 135
#
# Temperature: 1.293357274896604e-06
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 1.2286894111517737e-06
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 1.167254940594185e-06
# Neighour tour: [1, 0, 4, 2, 3]
# distance: 135
# Picked neighbour tour: [1, 0, 4, 2, 3]
# distance: 135
#
# Temperature: 1.1088921935644757e-06
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 1.053447583886252e-06
# Neighour tour: [1, 4, 0, 3, 2]
# distance: 140
# Picked neighbour tour: [1, 4, 0, 3, 2]
# distance: 140
#
# Temperature: 1.0007752046919394e-06
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 9.507364444573423e-07
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 9.031996222344751e-07
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 8.580396411227514e-07
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 8.151376590666138e-07
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 7.743807761132831e-07
# Neighour tour: [1, 3, 0, 2, 4]
# distance: 135
# Picked neighbour tour: [1, 3, 0, 2, 4]
# distance: 135
#
# Temperature: 7.35661737307619e-07
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 6.98878650442238e-07
# Neighour tour: [1, 3, 0, 2, 4]
# distance: 135
# Picked neighbour tour: [1, 3, 0, 2, 4]
# distance: 135
#
# Temperature: 6.63934717920126e-07
# Neighour tour: [1, 4, 0, 3, 2]
# distance: 140
# Picked neighbour tour: [1, 4, 0, 3, 2]
# distance: 140
#
# Temperature: 6.307379820241197e-07
# Neighour tour: [1, 4, 0, 3, 2]
# distance: 140
# Picked neighbour tour: [1, 4, 0, 3, 2]
# distance: 140
#
# Temperature: 5.992010829229137e-07
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 5.692410287767679e-07
# Neighour tour: [1, 4, 2, 0, 3]
# distance: 135
# Picked neighbour tour: [1, 4, 2, 0, 3]
# distance: 135
#
# Temperature: 5.407789773379295e-07
# Neighour tour: [1, 4, 0, 3, 2]
# distance: 140
# Picked neighbour tour: [1, 4, 0, 3, 2]
# distance: 140
#
# Temperature: 5.13740028471033e-07
# Neighour tour: [1, 4, 2, 0, 3]
# distance: 135
# Picked neighbour tour: [1, 4, 2, 0, 3]
# distance: 135
#
# Temperature: 4.880530270474813e-07
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 4.636503756951072e-07
# Neighour tour: [1, 4, 2, 0, 3]
# distance: 135
# Picked neighbour tour: [1, 4, 2, 0, 3]
# distance: 135
#
# Temperature: 4.404678569103518e-07
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 4.184444640648342e-07
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 3.975222408615925e-07
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 3.7764612881851285e-07
# Neighour tour: [4, 1, 0, 2, 3]
# distance: 140
# Picked neighbour tour: [4, 1, 0, 2, 3]
# distance: 140
#
# Temperature: 3.587638223775872e-07
# Neighour tour: [4, 1, 0, 2, 3]
# distance: 140
# Picked neighbour tour: [4, 1, 0, 2, 3]
# distance: 140
#
# Temperature: 3.408256312587078e-07
# Neighour tour: [4, 1, 0, 2, 3]
# distance: 140
# Picked neighbour tour: [4, 1, 0, 2, 3]
# distance: 140
#
# Temperature: 3.237843496957724e-07
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 3.075951322109838e-07
# Neighour tour: [1, 4, 2, 0, 3]
# distance: 135
# Picked neighbour tour: [1, 4, 2, 0, 3]
# distance: 135
#
# Temperature: 2.9221537560043456e-07
# Neighour tour: [4, 1, 0, 2, 3]
# distance: 140
# Picked neighbour tour: [4, 1, 0, 2, 3]
# distance: 140
#
# Temperature: 2.776046068204128e-07
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 2.6372437647939214e-07
# Neighour tour: [1, 4, 0, 3, 2]
# distance: 140
# Picked neighbour tour: [1, 4, 0, 3, 2]
# distance: 140
#
# Temperature: 2.505381576554225e-07
# Neighour tour: [1, 4, 2, 0, 3]
# distance: 135
# Picked neighbour tour: [1, 4, 2, 0, 3]
# distance: 135
#
# Temperature: 2.3801124977265136e-07
# Neighour tour: [0, 4, 1, 2, 3]
# distance: 140
# Picked neighbour tour: [0, 4, 1, 2, 3]
# distance: 140
#
# Temperature: 2.2611068728401878e-07
# Neighour tour: [4, 1, 0, 2, 3]
# distance: 140
# Picked neighbour tour: [4, 1, 0, 2, 3]
# distance: 140
#
# Temperature: 2.1480515291981785e-07
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 2.0406489527382694e-07
# Neighour tour: [1, 0, 4, 2, 3]
# distance: 135
# Picked neighbour tour: [1, 0, 4, 2, 3]
# distance: 135
#
# Temperature: 1.938616505101356e-07
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 1.841685679846288e-07
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 1.7496013958539734e-07
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 1.6621213260612747e-07
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 1.5790152597582108e-07
# Neighour tour: [1, 4, 0, 3, 2]
# distance: 140
# Picked neighbour tour: [1, 4, 0, 3, 2]
# distance: 140
#
# Temperature: 1.5000644967703e-07
# Neighour tour: [1, 3, 0, 2, 4]
# distance: 135
# Picked neighbour tour: [1, 3, 0, 2, 4]
# distance: 135
#
# Temperature: 1.425061271931785e-07
# Neighour tour: [1, 3, 0, 2, 4]
# distance: 135
# Picked neighbour tour: [1, 3, 0, 2, 4]
# distance: 135
#
# Temperature: 1.3538082083351956e-07
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 1.2861177979184357e-07
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 1.2218119080225138e-07
# Neighour tour: [1, 3, 0, 2, 4]
# distance: 135
# Picked neighbour tour: [1, 3, 0, 2, 4]
# distance: 135
#
# Temperature: 1.160721312621388e-07
# Neighour tour: [0, 4, 1, 2, 3]
# distance: 140
# Picked neighbour tour: [0, 4, 1, 2, 3]
# distance: 140
#
# Temperature: 1.1026852469903185e-07
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 1.0475509846408025e-07
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 9.951734354087623e-08
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 9.454147636383241e-08
# Neighour tour: [1, 4, 0, 3, 2]
# distance: 140
# Picked neighbour tour: [1, 4, 0, 3, 2]
# distance: 140
#
# Temperature: 8.981440254564079e-08
# Neighour tour: [1, 4, 0, 3, 2]
# distance: 140
# Picked neighbour tour: [1, 4, 0, 3, 2]
# distance: 140
#
# Temperature: 8.532368241835875e-08
# Neighour tour: [1, 0, 4, 2, 3]
# distance: 135
# Picked neighbour tour: [1, 0, 4, 2, 3]
# distance: 135
#
# Temperature: 8.105749829744081e-08
# Neighour tour: [1, 0, 4, 2, 3]
# distance: 135
# Picked neighbour tour: [1, 0, 4, 2, 3]
# distance: 135
#
# Temperature: 7.700462338256876e-08
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 7.315439221344031e-08
# Neighour tour: [0, 4, 1, 2, 3]
# distance: 140
# Picked neighbour tour: [0, 4, 1, 2, 3]
# distance: 140
#
# Temperature: 6.949667260276829e-08
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 6.602183897262987e-08
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 6.272074702399837e-08
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 5.9584709672798446e-08
# Neighour tour: [1, 3, 0, 2, 4]
# distance: 135
# Picked neighbour tour: [1, 3, 0, 2, 4]
# distance: 135
#
# Temperature: 5.660547418915852e-08
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 5.3775200479700594e-08
# Neighour tour: [0, 4, 1, 2, 3]
# distance: 140
# Picked neighbour tour: [0, 4, 1, 2, 3]
# distance: 140
#
# Temperature: 5.1086440455715564e-08
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 4.853211843292978e-08
# Neighour tour: [1, 4, 0, 3, 2]
# distance: 140
# Picked neighbour tour: [1, 4, 0, 3, 2]
# distance: 140
#
# Temperature: 4.610551251128329e-08
# Neighour tour: [1, 3, 0, 2, 4]
# distance: 135
# Picked neighbour tour: [1, 3, 0, 2, 4]
# distance: 135
#
# Temperature: 4.3800236885719123e-08
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 4.161022504143317e-08
# Neighour tour: [1, 4, 0, 3, 2]
# distance: 140
# Picked neighbour tour: [1, 4, 0, 3, 2]
# distance: 140
#
# Temperature: 3.9529713789361506e-08
# Neighour tour: [0, 4, 1, 2, 3]
# distance: 140
# Picked neighbour tour: [0, 4, 1, 2, 3]
# distance: 140
#
# Temperature: 3.7553228099893426e-08
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 3.567556669489875e-08
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 3.389178836015381e-08
# Neighour tour: [1, 4, 0, 3, 2]
# distance: 140
# Picked neighbour tour: [1, 4, 0, 3, 2]
# distance: 140
#
# Temperature: 3.219719894214612e-08
# Neighour tour: [1, 4, 2, 0, 3]
# distance: 135
# Picked neighbour tour: [1, 4, 2, 0, 3]
# distance: 135
#
# Temperature: 3.0587338995038816e-08
# Neighour tour: [1, 3, 0, 2, 4]
# distance: 135
# Picked neighbour tour: [1, 3, 0, 2, 4]
# distance: 135
#
# Temperature: 2.9057972045286873e-08
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 2.760507344302253e-08
# Neighour tour: [0, 4, 1, 2, 3]
# distance: 140
# Picked neighbour tour: [0, 4, 1, 2, 3]
# distance: 140
#
# Temperature: 2.62248197708714e-08
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 2.491357878232783e-08
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 2.3667899843211437e-08
# Neighour tour: [1, 4, 2, 0, 3]
# distance: 135
# Picked neighbour tour: [1, 4, 2, 0, 3]
# distance: 135
#
# Temperature: 2.2484504851050864e-08
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 2.1360279608498322e-08
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 2.0292265628073404e-08
# Neighour tour: [0, 4, 1, 2, 3]
# distance: 140
# Picked neighbour tour: [0, 4, 1, 2, 3]
# distance: 140
#
# Temperature: 1.9277652346669734e-08
# Neighour tour: [4, 1, 0, 2, 3]
# distance: 140
# Picked neighbour tour: [4, 1, 0, 2, 3]
# distance: 140
#
# Temperature: 1.8313769729336247e-08
# Neighour tour: [1, 4, 0, 3, 2]
# distance: 140
# Picked neighbour tour: [1, 4, 0, 3, 2]
# distance: 140
#
# Temperature: 1.7398081242869433e-08
# Neighour tour: [1, 3, 0, 2, 4]
# distance: 135
# Picked neighbour tour: [1, 3, 0, 2, 4]
# distance: 135
#
# Temperature: 1.652817718072596e-08
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 1.5701768321689663e-08
# Neighour tour: [3, 4, 0, 2, 1]
# distance: 155
# Picked neighbour tour: [3, 4, 0, 2, 1]
# distance: 155
#
# Temperature: 1.491667990560518e-08
# Neighour tour: [4, 1, 0, 2, 3]
# distance: 140
# Picked neighbour tour: [4, 1, 0, 2, 3]
# distance: 140
#
# Temperature: 1.417084591032492e-08
# Neighour tour: [0, 4, 1, 2, 3]
# distance: 140
# Picked neighbour tour: [0, 4, 1, 2, 3]
# distance: 140
#
# Temperature: 1.3462303614808673e-08
# Neighour tour: [1, 3, 0, 2, 4]
# distance: 135
# Picked neighbour tour: [1, 3, 0, 2, 4]
# distance: 135
#
# Temperature: 1.278918843406824e-08
# Neighour tour: [1, 4, 0, 3, 2]
# distance: 140
# Picked neighbour tour: [1, 4, 0, 3, 2]
# distance: 140
#
# Temperature: 1.2149729012364827e-08
# Neighour tour: [0, 4, 1, 2, 3]
# distance: 140
# Picked neighbour tour: [0, 4, 1, 2, 3]
# distance: 140
#
# Temperature: 1.1542242561746586e-08
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 1.0965130433659256e-08
# Neighour tour: [1, 0, 4, 2, 3]
# distance: 135
# Picked neighbour tour: [1, 0, 4, 2, 3]
# distance: 135
#
# Temperature: 1.0416873911976293e-08
# Neighour tour: [1, 0, 4, 2, 3]
# distance: 135
# Picked neighbour tour: [1, 0, 4, 2, 3]
# distance: 135
#
# Temperature: 9.896030216377477e-09
# Neighour tour: [2, 4, 0, 1, 3]
# distance: 135
# Picked neighbour tour: [2, 4, 0, 1, 3]
# distance: 135
#
# Temperature: 9.401228705558603e-09
# Neighour tour: [4, 1, 0, 2, 3]
# distance: 140
# Picked neighbour tour: [4, 1, 0, 2, 3]
# distance: 140
#
# Temperature: 8.931167270280672e-09
# Neighour tour: [0, 4, 1, 2, 3]
# distance: 140
# Picked neighbour tour: [0, 4, 1, 2, 3]
# distance: 140
#
# Temperature: 8.484608906766637e-09
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 8.060378461428306e-09
# Neighour tour: [1, 2, 0, 4, 3]
# distance: 155
# Picked neighbour tour: [1, 2, 0, 4, 3]
# distance: 155
#
# Temperature: 7.65735953835689e-09
# Neighour tour: [1, 4, 3, 2, 0]
# distance: 140
# Picked neighbour tour: [1, 4, 3, 2, 0]
# distance: 140
#
# Temperature: 7.274491561439045e-09
# Optimal Tour: [1, 3, 2, 0, 4]
# Optimal Distance: 125
